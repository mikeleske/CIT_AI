# %%
from utils import *

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
import xgboost as xgb

# %%
df_train = pd.read_csv('./data/train_10M.csv') 
df_train['pickup_datetime'] = df_train['pickup_datetime'].str.slice(0, 16)
df_train['pickup_datetime'] = pd.to_datetime(df_train['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')

# %%
# MinMaxScaler             : 3.20
# MaxAbsScaler             : 
# StandardScaler           : 
# RobustScaler             : 3.21
# Normalizer               : 
# QuantileTransformer      : 
# PowerTransformer         : 

scaler = 'MinMaxScaler'

# %%
df_train = add_features(df_train)
df_train = clean_df(df_train)
df_train = df_train.reset_index()
df_train = df_train.drop(['index'], axis=1)
df_train, lat_scaler, lon_scaler = scale_gps(df_train, scaler)
df_train = drop_date(df_train)
# Out:
# Old size: 10000000
# New size: 9633165

# %%
cols = df_train.columns.tolist()
cols.remove('fare_amount')

X = df_train[cols]
y = df_train['fare_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
matrix_train = xgb.DMatrix(X_train,label=y_train)
matrix_test = xgb.DMatrix(X_test,label=y_test)

# %%
# %%time

params = {
    'objective':'reg:squarederror',
    'eval_metric':'rmse',
    'silent': 0,
    'nthread': 8,
    'n_jobs': 8,
}

model = xgb.train(
    params=params,
    dtrain=matrix_train,
    num_boost_round=150,
    early_stopping_rounds=10,
    evals=[(matrix_test,'test')],
)
# Out:
# [11:13:18] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	test-rmse:10.4395
# Will train until test-rmse hasn't improved in 10 rounds.
# [1]	test-rmse:7.80591
# [2]	test-rmse:6.10063
# [3]	test-rmse:5.03774
# [4]	test-rmse:4.40858
# [5]	test-rmse:4.04439
# [6]	test-rmse:3.84007
# [7]	test-rmse:3.72596
# [8]	test-rmse:3.65521
# [9]	test-rmse:3.61207
# [10]	test-rmse:3.58521
# [11]	test-rmse:3.54
# [12]	test-rmse:3.51884
# [13]	test-rmse:3.51112
# [14]	test-rmse:3.50027
# [15]	test-rmse:3.4916
# [16]	test-rmse:3.48465
# [17]	test-rmse:3.47712
# [18]	test-rmse:3.46333
# [19]	test-rmse:3.45818
# [20]	test-rmse:3.45281
# [21]	test-rmse:3.44856
# [22]	test-rmse:3.4414
# [23]	test-rmse:3.43254
# [24]	test-rmse:3.42665
# [25]	test-rmse:3.41921
# [26]	test-rmse:3.41708
# [27]	test-rmse:3.41568
# [28]	test-rmse:3.40874
# [29]	test-rmse:3.3991
# [30]	test-rmse:3.39062
# [31]	test-rmse:3.3881
# [32]	test-rmse:3.38539
# [33]	test-rmse:3.38348
# [34]	test-rmse:3.38036
# [35]	test-rmse:3.37332
# [36]	test-rmse:3.36752
# [37]	test-rmse:3.3648
# [38]	test-rmse:3.36324
# [39]	test-rmse:3.36141
# [40]	test-rmse:3.35732
# [41]	test-rmse:3.3553
# [42]	test-rmse:3.35325
# [43]	test-rmse:3.35159
# [44]	test-rmse:3.34911
# [45]	test-rmse:3.34593
# [46]	test-rmse:3.34521
# [47]	test-rmse:3.34121
# [48]	test-rmse:3.33778
# [49]	test-rmse:3.33599
# [50]	test-rmse:3.33263
# [51]	test-rmse:3.33064
# [52]	test-rmse:3.32891
# [53]	test-rmse:3.32824
# [54]	test-rmse:3.32585
# [55]	test-rmse:3.32342
# [56]	test-rmse:3.32168
# [57]	test-rmse:3.31944
# [58]	test-rmse:3.31606
# [59]	test-rmse:3.31542
# [60]	test-rmse:3.31445
# [61]	test-rmse:3.3138
# [62]	test-rmse:3.31229
# [63]	test-rmse:3.31134
# [64]	test-rmse:3.31094
# [65]	test-rmse:3.31019
# [66]	test-rmse:3.30885
# [67]	test-rmse:3.30671
# [68]	test-rmse:3.30437
# [69]	test-rmse:3.30341
# [70]	test-rmse:3.3028
# [71]	test-rmse:3.3012
# [72]	test-rmse:3.30003
# [73]	test-rmse:3.29872
# [74]	test-rmse:3.29665
# [75]	test-rmse:3.29504
# [76]	test-rmse:3.29441
# [77]	test-rmse:3.29342
# [78]	test-rmse:3.29171
# [79]	test-rmse:3.28943
# [80]	test-rmse:3.2879
# [81]	test-rmse:3.28707
# [82]	test-rmse:3.28627
# [83]	test-rmse:3.28546
# [84]	test-rmse:3.28461
# [85]	test-rmse:3.28389
# [86]	test-rmse:3.28217
# [87]	test-rmse:3.2816
# [88]	test-rmse:3.28025
# [89]	test-rmse:3.27902
# [90]	test-rmse:3.27891
# [91]	test-rmse:3.27862
# [92]	test-rmse:3.27769
# [93]	test-rmse:3.27714
# [94]	test-rmse:3.27644
# [95]	test-rmse:3.27542
# [96]	test-rmse:3.27456
# [97]	test-rmse:3.27437
# [98]	test-rmse:3.27373
# [99]	test-rmse:3.27333
# [100]	test-rmse:3.27273
# [101]	test-rmse:3.27168
# [102]	test-rmse:3.27121
# [103]	test-rmse:3.27041
# [104]	test-rmse:3.2701
# [105]	test-rmse:3.26944
# [106]	test-rmse:3.26939
# [107]	test-rmse:3.26861
# [108]	test-rmse:3.26804
# [109]	test-rmse:3.267
# [110]	test-rmse:3.26669
# [111]	test-rmse:3.2664
# [112]	test-rmse:3.26593
# [113]	test-rmse:3.26538
# [114]	test-rmse:3.26484
# [115]	test-rmse:3.26468
# [116]	test-rmse:3.26438
# [117]	test-rmse:3.26427
# [118]	test-rmse:3.26383
# [119]	test-rmse:3.26357
# [120]	test-rmse:3.26303
# [121]	test-rmse:3.26249
# [122]	test-rmse:3.26261
# [123]	test-rmse:3.26185
# [124]	test-rmse:3.26149
# [125]	test-rmse:3.2609
# [126]	test-rmse:3.26086
# [127]	test-rmse:3.26052
# [128]	test-rmse:3.26002
# [129]	test-rmse:3.26011
# [130]	test-rmse:3.25968
# [131]	test-rmse:3.25965
# [132]	test-rmse:3.25924
# [133]	test-rmse:3.25883
# [134]	test-rmse:3.25714
# [135]	test-rmse:3.25687
# [136]	test-rmse:3.25673
# [137]	test-rmse:3.25606
# [138]	test-rmse:3.25594
# [139]	test-rmse:3.25536
# [140]	test-rmse:3.25512
# [141]	test-rmse:3.25476
# [142]	test-rmse:3.25431
# [143]	test-rmse:3.2542
# [144]	test-rmse:3.25393
# [145]	test-rmse:3.25349
# [146]	test-rmse:3.25241
# [147]	test-rmse:3.25186
# [148]	test-rmse:3.25096
# [149]	test-rmse:3.2508
# CPU times: user 3h 13min 59s, sys: 29.1 s, total: 3h 14min 28s
# Wall time: 25min 21s

# %%
y_pred = model.predict(matrix_test, ntree_limit=model.best_ntree_limit)
print('RMSE:', math.sqrt(mean_squared_error(y_test, y_pred)))
print('R^2 :', r2_score(y_test, y_pred))
# Out:
# RMSE: 3.250878855235616
# R^2 : 0.8823411421880564

# %%
plot_predictions(y_test, y_pred)

# %%
plt.figure(figsize=(10,10))
plt.barh(*zip(*model.get_fscore().items()))
plt.title('XGBoost Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ---
#
# # Creating the Kaggle submission file (prediction on official test set)

# %%
df_test = pd.read_csv('./data/test.csv') 
df_test['pickup_datetime'] = df_test['pickup_datetime'].str.slice(0, 16)
df_test['pickup_datetime'] = pd.to_datetime(df_test['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')

df_test = add_features(df_test)
df_test, lat_scaler, lon_scaler = scale_gps(df_test, scaler, lat_scaler, lon_scaler)
df_test = drop_date(df_test)

df_test = df_test.drop(['key'], axis=1)

# %%
pred_test = model.predict(xgb.DMatrix(df_test), ntree_limit = model.best_ntree_limit)

# %%
df_test = pd.read_csv('./data/test.csv') 

submission = pd.DataFrame({
        "key": df_test['key'],
        "fare_amount": pred_test.round(2)
})

submission.to_csv('03_2_taxi_fare_submission_default.csv',index=False)

# %%
from utils import *

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
import xgboost as xgb

# %%
df_train = pd.read_csv('./data/train_1M.csv', nrows=500000) 
df_train['pickup_datetime'] = df_train['pickup_datetime'].str.slice(0, 16)
df_train['pickup_datetime'] = pd.to_datetime(df_train['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')

# %%
# MinMaxScaler             : 
# MaxAbsScaler             : 
# StandardScaler           : 
# RobustScaler             : 
# Normalizer               : 
# QuantileTransformer      : 
# PowerTransformer         : 

scaler = 'MinMaxScaler'

# %%
df_train = add_features(df_train)
df_train = clean_df(df_train)
df_train = df_train.reset_index()
df_train = df_train.drop(['index'], axis=1)
df_train, lat_scaler, lon_scaler = scale_gps(df_train, scaler)
df_train = drop_date(df_train)
df_train = df_train.drop(['passenger_count'], axis=1)
# Out:
# Old size: 500000
# New size: 481794

# %%
cols = df_train.columns.tolist()
cols.remove('fare_amount')

X = df_train[cols]
y = df_train['fare_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
matrix_train = xgb.DMatrix(X_train,label=y_train)
matrix_test = xgb.DMatrix(X_test,label=y_test)

# %%
xgb_reg = xgb.XGBRegressor(tree_method="exact", predictor="cpu_predictor", verbosity=1, objective="reg:squarederror")

param_grid = {
    'n_estimators': [150],
    'max_depth': [5, 7, 9], 
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.4, 0.6, 0.8],
    'colsample_bylevel': [0.4, 0.6, 0.8],
    'learning_rate': [0.06, 0.075, 0.08, 0.1, 0.2],
    'min_child_weight': [1, 3, 5, 7, 9],
}

xgb_rscv = RandomizedSearchCV(xgb_reg, param_distributions=param_grid, 
                              scoring='neg_mean_squared_error', cv=10, 
                              verbose=3, random_state=40, n_jobs=-1)

search = xgb_rscv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 19.6min finished

# %%
import pprint as pp
pp.pprint(search.best_estimator_.get_params())
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 0.6,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.8,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 9,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 150,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:squarederror',
#  'predictor': 'cpu_predictor',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 0.9,
#  'tree_method': 'exact',
#  'verbosity': 1}

# %% [markdown]
# ---

# %%
df_train = pd.read_csv('./data/train_10M.csv') 
df_train['pickup_datetime'] = df_train['pickup_datetime'].str.slice(0, 16)
df_train['pickup_datetime'] = pd.to_datetime(df_train['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')

# %%
del(lat_scaler)
del(lon_scaler)

# %%
df_train = add_features(df_train)
df_train = clean_df(df_train)
df_train = df_train.reset_index()
df_train = df_train.drop(['index'], axis=1)
df_train, pca = pca_gps(df_train)
df_train, lat_scaler, lon_scaler = scale_gps(df_train, scaler)
df_train = drop_date(df_train)
df_train = df_train.drop(['passenger_count'], axis=1)
# Out:
# Old size: 10000000
# New size: 9633165

# %%
cols = df_train.columns.tolist()
cols.remove('fare_amount')

X = df_train[cols]
y = df_train['fare_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
matrix_train = xgb.DMatrix(X_train,label=y_train)
matrix_test = xgb.DMatrix(X_test,label=y_test)

# %%
# %%time

params = {
    'objective':'reg:squarederror',
    'eval_metric':'rmse',
    #
    'n_estimators': search.best_estimator_.get_params()['n_estimators'],
    'max_depth': search.best_estimator_.get_params()['max_depth'],
    'subsample': search.best_estimator_.get_params()['subsample'],
    'colsample_bytree': 0.6, #search.best_estimator_.get_params()['colsample_bytree'],
    'colsample_bylevel': search.best_estimator_.get_params()['colsample_bylevel'],
    'learning_rate': search.best_estimator_.get_params()['learning_rate'],
    'min_child_weight': search.best_estimator_.get_params()['min_child_weight'],
    #
    'silent': 0,
    'nthread': 8,
    'n_jobs': 8,
}

model = xgb.train(
    params=params,
    dtrain=matrix_train,
    num_boost_round=150,
    early_stopping_rounds=10,
    evals=[(matrix_test,'test')],
)
# Out:
# [19:17:33] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	test-rmse:12.9968
# Will train until test-rmse hasn't improved in 10 rounds.
# [1]	test-rmse:11.8033
# [2]	test-rmse:10.7859
# [3]	test-rmse:9.86374
# [4]	test-rmse:9.01415
# [5]	test-rmse:8.26065
# [6]	test-rmse:7.62729
# [7]	test-rmse:7.03162
# [8]	test-rmse:6.50009
# [9]	test-rmse:6.03733
# [10]	test-rmse:5.68228
# [11]	test-rmse:5.32405
# [12]	test-rmse:5.01193
# [13]	test-rmse:4.74511
# [14]	test-rmse:4.51776
# [15]	test-rmse:4.32182
# [16]	test-rmse:4.16765
# [17]	test-rmse:4.02345
# [18]	test-rmse:3.90959
# [19]	test-rmse:3.81497
# [20]	test-rmse:3.72464
# [21]	test-rmse:3.65204
# [22]	test-rmse:3.58766
# [23]	test-rmse:3.53782
# [24]	test-rmse:3.49615
# [25]	test-rmse:3.46047
# [26]	test-rmse:3.43012
# [27]	test-rmse:3.40378
# [28]	test-rmse:3.37733
# [29]	test-rmse:3.35535
# [30]	test-rmse:3.33644
# [31]	test-rmse:3.32137
# [32]	test-rmse:3.30805
# [33]	test-rmse:3.2949
# [34]	test-rmse:3.2827
# [35]	test-rmse:3.27231
# [36]	test-rmse:3.26241
# [37]	test-rmse:3.25405
# [38]	test-rmse:3.24675
# [39]	test-rmse:3.24076
# [40]	test-rmse:3.2349
# [41]	test-rmse:3.22955
# [42]	test-rmse:3.22532
# [43]	test-rmse:3.22003
# [44]	test-rmse:3.21665
# [45]	test-rmse:3.21178
# [46]	test-rmse:3.20895
# [47]	test-rmse:3.20705
# [48]	test-rmse:3.20305
# [49]	test-rmse:3.19916
# [50]	test-rmse:3.19562
# [51]	test-rmse:3.19221
# [52]	test-rmse:3.19019
# [53]	test-rmse:3.1869
# [54]	test-rmse:3.18446
# [55]	test-rmse:3.18225
# [56]	test-rmse:3.17931
# [57]	test-rmse:3.17712
# [58]	test-rmse:3.17569
# [59]	test-rmse:3.17393
# [60]	test-rmse:3.17114
# [61]	test-rmse:3.16811
# [62]	test-rmse:3.16663
# [63]	test-rmse:3.16543
# [64]	test-rmse:3.16343
# [65]	test-rmse:3.16114
# [66]	test-rmse:3.15993
# [67]	test-rmse:3.15752
# [68]	test-rmse:3.15658
# [69]	test-rmse:3.15455
# [70]	test-rmse:3.15305
# [71]	test-rmse:3.15153
# [72]	test-rmse:3.14989
# [73]	test-rmse:3.14878
# [74]	test-rmse:3.14683
# [75]	test-rmse:3.14646
# [76]	test-rmse:3.14605
# [77]	test-rmse:3.14457
# [78]	test-rmse:3.14269
# [79]	test-rmse:3.1415
# [80]	test-rmse:3.14053
# [81]	test-rmse:3.13799
# [82]	test-rmse:3.13725
# [83]	test-rmse:3.13645
# [84]	test-rmse:3.13565
# [85]	test-rmse:3.13474
# [86]	test-rmse:3.13395
# [87]	test-rmse:3.13319
# [88]	test-rmse:3.13248
# [89]	test-rmse:3.13063
# [90]	test-rmse:3.12925
# [91]	test-rmse:3.12812
# [92]	test-rmse:3.12751
# [93]	test-rmse:3.12623
# [94]	test-rmse:3.12496
# [95]	test-rmse:3.12377
# [96]	test-rmse:3.12316
# [97]	test-rmse:3.12217
# [98]	test-rmse:3.12028
# [99]	test-rmse:3.11889
# [100]	test-rmse:3.11748
# [101]	test-rmse:3.11659
# [102]	test-rmse:3.11587
# [103]	test-rmse:3.11504
# [104]	test-rmse:3.1141
# [105]	test-rmse:3.11388
# [106]	test-rmse:3.1124
# [107]	test-rmse:3.11163
# [108]	test-rmse:3.11029
# [109]	test-rmse:3.10907
# [110]	test-rmse:3.10789
# [111]	test-rmse:3.10765
# [112]	test-rmse:3.1069
# [113]	test-rmse:3.10558
# [114]	test-rmse:3.10469
# [115]	test-rmse:3.10397
# [116]	test-rmse:3.10332
# [117]	test-rmse:3.10275
# [118]	test-rmse:3.10244
# [119]	test-rmse:3.10147
# [120]	test-rmse:3.10131
# [121]	test-rmse:3.10068
# [122]	test-rmse:3.09991
# [123]	test-rmse:3.09939
# [124]	test-rmse:3.09877
# [125]	test-rmse:3.09823
# [126]	test-rmse:3.0978
# [127]	test-rmse:3.09713
# [128]	test-rmse:3.09688
# [129]	test-rmse:3.09629
# [130]	test-rmse:3.09551
# [131]	test-rmse:3.09496
# [132]	test-rmse:3.09468
# [133]	test-rmse:3.09413
# [134]	test-rmse:3.09328
# [135]	test-rmse:3.09284
# [136]	test-rmse:3.09254
# [137]	test-rmse:3.09202
# [138]	test-rmse:3.09135
# [139]	test-rmse:3.09085
# [140]	test-rmse:3.09001
# [141]	test-rmse:3.08971
# [142]	test-rmse:3.08925
# [143]	test-rmse:3.08891
# [144]	test-rmse:3.08817
# [145]	test-rmse:3.08813
# [146]	test-rmse:3.08785
# [147]	test-rmse:3.08721
# [148]	test-rmse:3.08661
# [149]	test-rmse:3.08605
# CPU times: user 3h 54min 31s, sys: 26.8 s, total: 3h 54min 58s
# Wall time: 30min 14s

# %%
y_pred = model.predict(matrix_test, ntree_limit=model.best_ntree_limit)
print('RMSE:', math.sqrt(mean_squared_error(y_test, y_pred)))
print('R^2 :', r2_score(y_test, y_pred))
# Out:
# RMSE: 3.086123348559516
# R^2 : 0.8929294720916781

# %%
plot_predictions(y_test, y_pred)

# %%
plt.figure(figsize=(10,10))
plt.barh(*zip(*model.get_fscore().items()))
plt.title('XGBoost Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ---
#
# # Creating the Kaggle submission file (prediction on official test set)

# %%
df_test = pd.read_csv('./data/test.csv') 
df_test['pickup_datetime'] = df_test['pickup_datetime'].str.slice(0, 16)
df_test['pickup_datetime'] = pd.to_datetime(df_test['pickup_datetime'], utc=True, format='%Y-%m-%d %H:%M')

df_test = add_features(df_test)
df_test, pca = pca_gps(df_test)
df_test, lat_scaler, lon_scaler = scale_gps(df_test, scaler, lat_scaler, lon_scaler)
df_test = drop_date(df_test)
df_test = df_test.drop(['passenger_count'], axis=1)

df_test = df_test.drop(['key'], axis=1)

# %%
pred_test = model.predict(xgb.DMatrix(df_test), ntree_limit = model.best_ntree_limit)

# %%
df_test = pd.read_csv('./data/test.csv') 

submission = pd.DataFrame({
        "key": df_test['key'],
        "fare_amount": pred_test.round(2)
})

submission.to_csv('03_4_taxi_fare_submission_default.csv',index=False)
